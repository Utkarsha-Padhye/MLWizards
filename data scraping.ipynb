# %%
from bs4 import BeautifulSoup
import requests
url = "https://stats.espncricinfo.com/ci/engine/player/34102.html?class=2;template=results;type=allround"
req = requests.get(url)
soup = BeautifulSoup(req.text, "html.parser")
print(soup.title)
# Out:
# <title>All-round records | One-Day Internationals | Cricinfo Statsguru | ESPNcricinfo.com</title>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage = requests.get('https://stats.espncricinfo.com/ci/engine/player/34102.html?class=2;template=results;type=allround').text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
#table_list = (soup.find_all('table')[0])

# %%
table = (soup.find_all('table', class_='engineTable')[2])

# %%
title = (table.find_all('th'))
title_new = []
avg_sum = []
for title in title:
         title_new.append(title.text)
print(title_new)
# Out:
# ['Grouping', 'Span', 'Mat', 'Runs', 'HS', 'Bat Av', '100', 'Wkts', 'BBI', 'Bowl Av', '5', 'Ct', 'St', 'Ave Diff', '']

# %%
avg_data = table.find_all('td')
avg_sum=[]
for avg_data in avg_data:
  avg_sum.append(avg_data.text)

print(avg_sum)
# Out:
# ['overall', '2007-2023', '252', '10112', '264', '48.61', '30', '8', '2/27', '64.37', '0', '91', '0', '-15.75', 'Profile']

# %%
#caption=[]
#th = []
#for i in table:
#  print('utk' , i)
 # caption.append(i.find_all('caption'))
 # th.append(i.find_all('th', class_='head'))

# %%
df = pd.DataFrame([avg_sum], columns=title_new)

# %%
df
# Out:
#                  Span  Mat   Runs   HS Bat Av 100 Wkts   BBI Bowl Av  5  Ct  \
# 0  overall  2007-2023  252  10112  264  48.61  30    8  2/27   64.37  0  91
#
#   St Ave Diff
# 0  0   -15.75  Profile

# %%
# working fin till this

# %%
table = (soup.find_all('table', class_='engineTable')[3])

# %%
# !pip install beautifulsoup4

# %%
career_summary = (table.find_all('tr'))
#title_new1 = []
#for Career_title in Career_title:
#         title_new1.append(Career_title.find_all('td').text)
#print(title_new1)

# %%
car = career_summary[1]
car = car.find_all('td')
car_sum = []
for car in car:
  car_sum.append(car.text.strip())
print(car_sum)
# Out:
# ['v Afghanistan', '2014-2019', '2', '19', '18*', '19.00', '0', '-', '-', '-', '-', '0', '0', '-', '']

# %%
car = career_summary[1]
car = car.find_all('td')
car_sum = []
for car in car:
  car_sum.append(car.text.strip())
print(car_sum)
# Out:
# ['v Afghanistan', '2014-2019', '2', '19', '18*', '19.00', '0', '-', '-', '-', '-', '0', '0', '-', '']

# %%
x = []
for i in career_summary:
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-238-cd5988614554> in <cell line: 2>()
#       1 x = []
#       2 for i in career_summary:
# ----> 3   x[i] = i.find_all('td')
#
# TypeError: list indices must be integers or slices, not Tag

# %%
# !pip install html-table-parser-python3

# %%
# Library for opening url and creating
# requests
import urllib.request

# pretty-print python data structures
from pprint import pprint

# for parsing all the tables present
# on the website
from html_table_parser.parser import HTMLTableParser

# for converting the parsed data in a
# pandas dataframe
import pandas as pd


# Opens a website and read its
# binary contents (HTTP Response Body)
def url_get_contents(url):

	# Opens a website and read its
	# binary contents (HTTP Response Body)

	#making request to the website
	req = urllib.request.Request(url=url)
	f = urllib.request.urlopen(req)

	#reading contents of the website
	return f.read()

# defining the html contents of a URL.
xhtml = url_get_contents('https://stats.espncricinfo.com/ci/engine/player/34102.html?class=2;template=results;type=allround').decode('utf-8')

# Defining the HTMLTableParser object
p = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p.feed(xhtml)

# Now finally obtaining the data of
# the table required
###pprint(p.tables[3])

# converting the parsed data to
# dataframe
#print("\n\nPANDAS DATAFRAME\n")
df1 = pd.DataFrame(p.tables[3])

# %%
df1
# Out:
#                             0          1     2     3     4       5     6   \
# 0                     Grouping       Span   Mat  Runs    HS  Bat Av   100
# 1                v Afghanistan  2014-2019     2    19   18*   19.00     0
# 2                  v Australia  2007-2023    44  2332   209   58.30     8
# 3                 v Bangladesh  2008-2023    16   738   137   56.76     3
# 4                    v England  2008-2022    19   637  137*   45.50     2
# ..                         ...        ...   ...   ...   ...     ...   ...
# 149                                  None  None  None  None    None  None
# 150          tournament finals  2008-2023    11   256    66   25.60     0
# 151     tournament semi-finals  2013-2019     4   191  123*   63.66     1
# 152  tournament quarter-finals  2015-2015     1   137   137  137.00     1
# 153        preliminary matches  2008-2023    78  2990   140   46.71     9
#
#        7     8        9     10    11    12        13    14
# ...

# %%
table = (soup.find_all('table', class_='engineTable')[3])
data = []
for row in table.find_all('tr'):
    row_data = []
    for cell in row.find_all('td'):
        row_data.append(cell.text)
    data.append(row_data)

# %%
df_new = pd.DataFrame(data)

# %%
df_new
# Out:
#                             0          1     2     3     4       5     6   \
# 0                         None       None  None  None  None    None  None
# 1                v Afghanistan  2014-2019     2    19   18*   19.00     0
# 2                  v Australia  2007-2023    44  2332   209   58.30     8
# 3                 v Bangladesh  2008-2023    16   738   137   56.76     3
# 4                    v England  2008-2022    19   637  137*   45.50     2
# ..                         ...        ...   ...   ...   ...     ...   ...
# 149                                  None  None  None  None    None  None
# 150          tournament finals  2008-2023    11   256    66   25.60     0
# 151     tournament semi-finals  2013-2019     4   191  123*   63.66     1
# 152  tournament quarter-finals  2015-2015     1   137   137  137.00     1
# 153        preliminary matches  2008-2023    78  2990   140   46.71     9
#
#        7     8      9     10    11    12      13    14
# ...
